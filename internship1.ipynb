# %% [markdown]
# <a href="https://colab.research.google.com/github/alekhya5886/Customer_churn_production/blob/main/internship1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Preprocessing:
# - Load the provided dataset and perform initial data exploration.

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/customer_churn_large_dataset.csv')

print(df.head())
print(df.info())
# Out:
#    CustomerID        Name  Age  Gender     Location  \
# 0           1  Customer_1   63    Male  Los Angeles
# 1           2  Customer_2   62  Female     New York
# 2           3  Customer_3   24  Female  Los Angeles
# 3           4  Customer_4   36  Female        Miami
# 4           5  Customer_5   46  Female        Miami
#
#    Subscription_Length_Months  Monthly_Bill  Total_Usage_GB  Churn
# 0                          17         73.36             236      0
# 1                           1         48.76             172      0
# 2                           5         85.47             460      0
# 3                           3         97.94             297      1
# 4                          19         58.14             266      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
# ...

# %% [markdown]
# - Handle missing data and outliers.
# - Prepare the data for machine learning by encoding categorical variables and splitting it into
# training and testing sets.

# %%
print(df.isnull().sum())

df['Subscription_Length_Months'].fillna(df['Subscription_Length_Months'].median(), inplace=True)
# Out:
# CustomerID                    0
# Name                          0
# Age                           0
# Gender                        0
# Location                      0
# Subscription_Length_Months    0
# Monthly_Bill                  0
# Total_Usage_GB                0
# Churn                         0
# dtype: int64

# %% [markdown]
# # Feature Engineering:
# - Generate relevant features from the dataset that can help improve the model's prediction
# accuracy.
# - Apply feature scaling or normalization if necessary.

# %%
df['used_service_X'] = df['Total_Usage_GB'] > 0

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['scaled_numeric_column'] = scaler.fit_transform(df[['Subscription_Length_Months']])

# %% [markdown]
# # Model Building:
# - Choose appropriate machine learning algorithms (e.g., logistic regression, random forest, or
# neural networks).
# - Train and validate the selected model on the training dataset.
# - Evaluate the model's performance using appropriate metrics (e.g., accuracy, precision, recall,
# F1-score).

# %%
import pandas as pd
import numpy as np

df.head()
column_name = 'CustomerID'
df[column_name] = pd.to_numeric(df[column_name], errors='coerce')
df.to_csv('modified_file.csv', index=False)

# %%
import pandas as pd

df['Name'] = df['Name'].astype(str)
df['Name'] = df['Name'].str[9:]

binary_columns = ['CustomerID','Name', 'Gender', 'Location','Subscription_Length_Months','Subscription_Length_Months','Total_Usage_GB']
for column in binary_columns:
    df[column] = df[column].astype('category')
    df[column] = df[column].cat.codes
df.to_csv('output.csv', index=False)
df.head()
# Out:
#    CustomerID  Name  Age  Gender  Location  Subscription_Length_Months  \
# 0           0     0   63       1         2                          16
# 1           1     0   62       0         4                           0
# 2           2     0   24       0         2                           4
# 3           3     0   36       0         3                           2
# 4           4     0   46       0         3                          18
#
#    Monthly_Bill  Total_Usage_GB  Churn
# 0         73.36             186      0
# 1         48.76             122      0
# 2         85.47             410      0
# 3         97.94             247      1
# 4         58.14             216      0

# %%
x=pd.DataFrame(df.iloc[:,:-1])
x
# Out:
#        CustomerID  Name  Age  Gender  Location  Subscription_Length_Months  \
# 0               0     0   63       1         2                          16
# 1               1     0   62       0         4                           0
# 2               2     0   24       0         2                           4
# 3               3     0   36       0         3                           2
# 4               4     0   46       0         3                          18
# ...           ...   ...  ...     ...       ...                         ...
# 99995       99995     0   33       1         1                          22
# 99996       99996     0   62       0         4                          18
# 99997       99997     0   64       1         0                          16
# 99998       99998     0   51       0         4                          19
# 99999       99999     0   27       0         2                          18
#
#        Monthly_Bill  Total_Usage_GB
# ...

# %%
y= pd.DataFrame(df.iloc[:,-1])
y
# Out:
#        Churn
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ...      ...
# 99995      1
# 99996      0
# 99997      1
# 99998      1
# 99999      1
#
# [100000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train,y_test = train_test_split(x,y,test_size=0.20)
df['CustomerID'] = df['CustomerID'].fillna(df['CustomerID'].mode()[0])

# %%
from sklearn.ensemble import RandomForestRegressor
regressor =RandomForestRegressor(n_estimators=20,random_state=0)
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)
# Out:
# <ipython-input-105-bcf682c2ef2b>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train,y_train)

# %%
import numpy as np

unique_values_pred = np.unique(y_pred)
print(unique_values_pred)
# Out:
# [0.47993858 0.48008719 0.48014517 ... 0.51169173 0.51197827 0.51238956]

# %%
import numpy as np

unique_values = np.unique(y_test)
print(unique_values)
# Out:
# [0 1]

# %% [markdown]
# # Model Optimization:
#  - cross validation

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error
import numpy as np

X = df[['CustomerID','Name','Age','Gender','Location','Subscription_Length_Months','Monthly_Bill','Total_Usage_GB']]
y = df['Churn']

model = LinearRegression()

y_pred = cross_val_predict(model, X, y, cv=5)

mse = mean_squared_error(y, y_pred)

print("Mean squared error:", mse)
# Out:
# Mean squared error: 0.25002315411364134

# %% [markdown]
# # Model Deployment:
# - Once satisfied with the model's performance, deploy it into a production-like
# environment (you can simulate this in a development environment).
# - Ensure the model can take new customer data as input and provide churn predictions.
